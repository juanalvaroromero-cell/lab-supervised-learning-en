# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span></li><li><span><a href="#Challenge-1---Explore-The-Dataset" data-toc-modified-id="Challenge-1---Explore-The-Dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Challenge 1 - Explore The Dataset</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Explore-the-data-from-an-bird's-eye-view." data-toc-modified-id="Explore-the-data-from-an-bird's-eye-view.-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>Explore the data from an bird's-eye view.</a></span></li><li><span><a href="#Next,-evaluate-if-the-columns-in-this-dataset-are-strongly-correlated." data-toc-modified-id="Next,-evaluate-if-the-columns-in-this-dataset-are-strongly-correlated.-2.0.0.2"><span class="toc-item-num">2.0.0.2&nbsp;&nbsp;</span>Next, evaluate if the columns in this dataset are strongly correlated.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-2---Remove-Column-Collinearity." data-toc-modified-id="Challenge-2---Remove-Column-Collinearity.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Challenge 2 - Remove Column Collinearity.</a></span></li><li><span><a href="#Challenge-3---Handle-Missing-Values" data-toc-modified-id="Challenge-3---Handle-Missing-Values-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Challenge 3 - Handle Missing Values</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#In-the-cells-below,-handle-the-missing-values-from-the-dataset.-Remember-to-comment-the-rationale-of-your-decisions." data-toc-modified-id="In-the-cells-below,-handle-the-missing-values-from-the-dataset.-Remember-to-comment-the-rationale-of-your-decisions.-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>In the cells below, handle the missing values from the dataset. Remember to comment the rationale of your decisions.</a></span></li><li><span><a href="#Again,-examine-the-number-of-missing-values-in-each-column." data-toc-modified-id="Again,-examine-the-number-of-missing-values-in-each-column.-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>Again, examine the number of missing values in each column.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-4---Handle-WHOIS_*-Categorical-Data" data-toc-modified-id="Challenge-4---Handle-WHOIS_*-Categorical-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Challenge 4 - Handle <code>WHOIS_*</code> Categorical Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#In-the-cells-below,-fix-the-country-values-as-intructed-above." data-toc-modified-id="In-the-cells-below,-fix-the-country-values-as-intructed-above.-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span>In the cells below, fix the country values as intructed above.</a></span></li><li><span><a href="#If-a-limited-number-of-values-account-for-the-majority-of-data,-we-can-retain-these-top-values-and-re-label-all-other-rare-values." data-toc-modified-id="If-a-limited-number-of-values-account-for-the-majority-of-data,-we-can-retain-these-top-values-and-re-label-all-other-rare-values.-5.0.0.2"><span class="toc-item-num">5.0.0.2&nbsp;&nbsp;</span>If a limited number of values account for the majority of data, we can retain these top values and re-label all other rare values.</a></span></li><li><span><a href="#After-verifying,-now-let's-keep-the-top-10-values-of-the-column-and-re-label-other-columns-with-OTHER." data-toc-modified-id="After-verifying,-now-let's-keep-the-top-10-values-of-the-column-and-re-label-other-columns-with-OTHER.-5.0.0.3"><span class="toc-item-num">5.0.0.3&nbsp;&nbsp;</span>After verifying, now let's keep the top 10 values of the column and re-label other columns with <code>OTHER</code>.</a></span></li><li><span><a href="#In-the-next-cell,-drop-['WHOIS_STATEPRO',-'WHOIS_REGDATE',-'WHOIS_UPDATED_DATE']." data-toc-modified-id="In-the-next-cell,-drop-['WHOIS_STATEPRO',-'WHOIS_REGDATE',-'WHOIS_UPDATED_DATE'].-5.0.0.4"><span class="toc-item-num">5.0.0.4&nbsp;&nbsp;</span>In the next cell, drop <code>['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']</code>.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-5---Handle-Remaining-Categorical-Data-&amp;-Convert-to-Ordinal" data-toc-modified-id="Challenge-5---Handle-Remaining-Categorical-Data-&amp;-Convert-to-Ordinal-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Challenge 5 - Handle Remaining Categorical Data &amp; Convert to Ordinal</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#URL-is-easy.-We'll-simply-drop-it-because-it-has-too-many-unique-values-that-there's-no-way-for-us-to-consolidate." data-toc-modified-id="URL-is-easy.-We'll-simply-drop-it-because-it-has-too-many-unique-values-that-there's-no-way-for-us-to-consolidate.-6.0.0.1"><span class="toc-item-num">6.0.0.1&nbsp;&nbsp;</span><code>URL</code> is easy. We'll simply drop it because it has too many unique values that there's no way for us to consolidate.</a></span></li><li><span><a href="#Print-the-unique-value-counts-of-CHARSET.-You-see-there-are-only-a-few-unique-values.-So-we-can-keep-it-as-it-is." data-toc-modified-id="Print-the-unique-value-counts-of-CHARSET.-You-see-there-are-only-a-few-unique-values.-So-we-can-keep-it-as-it-is.-6.0.0.2"><span class="toc-item-num">6.0.0.2&nbsp;&nbsp;</span>Print the unique value counts of <code>CHARSET</code>. You see there are only a few unique values. So we can keep it as it is.</a></span></li><li><span><a href="#Before-you-think-of-your-own-solution,-don't-read-the-instructions-that-come-next." data-toc-modified-id="Before-you-think-of-your-own-solution,-don't-read-the-instructions-that-come-next.-6.0.0.3"><span class="toc-item-num">6.0.0.3&nbsp;&nbsp;</span>Before you think of your own solution, don't read the instructions that come next.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-6---Modeling,-Prediction,-and-Evaluation" data-toc-modified-id="Challenge-6---Modeling,-Prediction,-and-Evaluation-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Challenge 6 - Modeling, Prediction, and Evaluation</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#In-this-lab,-we-will-try-two-different-models-and-compare-our-results." data-toc-modified-id="In-this-lab,-we-will-try-two-different-models-and-compare-our-results.-7.0.0.1"><span class="toc-item-num">7.0.0.1&nbsp;&nbsp;</span>In this lab, we will try two different models and compare our results.</a></span></li><li><span><a href="#Our-second-algorithm-is-is-DecisionTreeClassifier" data-toc-modified-id="Our-second-algorithm-is-is-DecisionTreeClassifier-7.0.0.2"><span class="toc-item-num">7.0.0.2&nbsp;&nbsp;</span>Our second algorithm is is DecisionTreeClassifier</a></span></li><li><span><a href="#We'll-create-another-DecisionTreeClassifier-model-with-max_depth=5." data-toc-modified-id="We'll-create-another-DecisionTreeClassifier-model-with-max_depth=5.-7.0.0.3"><span class="toc-item-num">7.0.0.3&nbsp;&nbsp;</span>We'll create another DecisionTreeClassifier model with max_depth=5.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Bonus-Challenge---Feature-Scaling" data-toc-modified-id="Bonus-Challenge---Feature-Scaling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Bonus Challenge - Feature Scaling</a></span></li></ul></div>

# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import your libraries:

# %matplotlib inline

import numpy as np
import pandas as pd

# %% [markdown]
# In this lab, we will explore a dataset that describes websites with different features and labels them either benign or malicious . We will use supervised learning algorithms to figure out what feature patterns malicious websites are likely to have and use our model to predict malicious websites.
#
# Your features will be:
#
# + URL: it is the anonymous identification of the URL analyzed in the study
# + URL_LENGTH: it is the number of characters in the URL
# + NUMBER_SPECIAL_CHARACTERS: it is number of special characters identified in the URL, such as, “/”, “%”, “#”, “&”, “. “, “=”
# + CHARSET: it is a categorical value and its meaning is the character encoding standard (also called character set).
# + SERVER: it is a categorical value and its meaning is the operative system of the server got from the packet response.
# + CONTENT_LENGTH: it represents the content size of the HTTP header.
# + WHOIS_COUNTRY: it is a categorical variable, its values are the countries we got from the server response (specifically, our script used the API of Whois).
# + WHOIS_STATEPRO: it is a categorical variable, its values are the states we got from the server response (specifically, our script used the API of Whois).
# + WHOIS_REGDATE: Whois provides the server registration date, so, this variable has date values with format DD/MM/YYY HH:MM
# + WHOIS_UPDATED_DATE: Through the Whois we got the last update date from the server analyzed
# + TCP_CONVERSATION_EXCHANGE: This variable is the number of TCP packets exchanged between the server and our honeypot client
# + DIST_REMOTE_TCP_PORT: it is the number of the ports detected and different to TCP
# + REMOTE_IPS: this variable has the total number of IPs connected to the honeypot
# + APP_BYTES: this is the number of bytes transfered
# + SOURCE_APP_PACKETS: packets sent from the honeypot to the server
# + REMOTE_APP_PACKETS: packets received from the server
# + APP_PACKETS: this is the total number of IP packets generated during the communication between the honeypot and the server
# + DNS_QUERY_TIMES: this is the number of DNS packets generated during the communication between the honeypot and the server
# + TYPE: this is a categorical variable, its values represent the type of web page analyzed, specifically, 1 is for malicious websites and 0 is for benign websites
#
# # Challenge 1 - Explore The Dataset
#
# Let's start by exploring the dataset. First load the data file:
#
#
# *Source: [kaggle](https://www.kaggle.com/viratkothari/malicious-and-benign-websites-classification)*

# %%
websites = pd.read_csv('../website.csv')

# %% [markdown]
# #### Explore the data from an bird's-eye view.
#
# You should already been very familiar with the procedures now so we won't provide the instructions step by step. Reflect on what you did in the previous labs and explore the dataset.
#
# Things you'll be looking for:
#
# * What the dataset looks like?
# * What are the data types?
# * Which columns contain the features of the websites?
# * Which column contains the feature we will predict? What is the code standing for benign vs malicious websites?
# * Do we need to transform any of the columns from categorical to ordinal values? If so what are these columns?
#
# Feel free to add additional cells for your explorations. Make sure to comment what you find out.

# %%
# What the dataset looks like?
# 1. Basic exploration - Bird's-eye view
# Display the first few rows to understand the structure
print("First 5 rows of the dataset:")
websites.head()
# Out:
# First 5 rows of the dataset:
#        URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0   M0_109          16                          7  iso-8859-1
# 1  B0_2314          16                          6       UTF-8
# 2   B0_911          16                          6    us-ascii
# 3   B0_113          17                          6  ISO-8859-1
# 4   B0_403          17                          6       UTF-8
#
#                   SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                  nginx           263.0           NaN            NaN
# 1          Apache/2.4.10         15087.0           NaN            NaN
# 2  Microsoft-HTTPAPI/2.0           324.0           NaN            NaN
# 3                  nginx           162.0            US             AK
# 4                    NaN        124140.0            US             TX
#
#       WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# ...

# %%
# What are the data types?
# 2. Data integrity and types
# Check data types and identify missing values (NaN)
print("\nDataset Information (Data types and Nulls):")
print(websites.info())

# Summarize missing values per column
null_counts = websites.isnull().sum()
print("\nMissing values per column:")
print(null_counts[null_counts > 0])
# Out:
# Dataset Information (Data types and Nulls):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        1781 non-null   object
#  1   URL_LENGTH                 1781 non-null   int64
#  2   NUMBER_SPECIAL_CHARACTERS  1781 non-null   int64
#  3   CHARSET                    1774 non-null   object
#  4   SERVER                     1605 non-null   object
#  5   CONTENT_LENGTH             969 non-null    float64
#  6   WHOIS_COUNTRY              1475 non-null   object
#  7   WHOIS_STATEPRO             1419 non-null   object
#  8   WHOIS_REGDATE              1654 non-null   object
#  9   WHOIS_UPDATED_DATE         1642 non-null   object
#  10  TCP_CONVERSATION_EXCHANGE  1781 non-null   int64
#  11  DIST_REMOTE_TCP_PORT       1781 non-null   int64
# ...

# %%
# Which columns contain the features of the websites?
# ALL EXCEPT URL BECAUSE IS A UNIQUE IDENTIFICATOR AND DON'T HELP FOR PREDICT
start_feature = 'URL_LENGTH'
end_feature = 'DNS_QUERY_TIMES'

# 2. Slice the dataframe to select all columns between them (inclusive)
# .loc allows us to select columns by name from start to finish
features = websites.loc[:, start_feature:end_feature]
print(features.columns)
print("\nFeature data types:")
print(features.dtypes)
# Out:
# Index(['URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CHARSET', 'SERVER',
#        'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'WHOIS_STATEPRO', 'WHOIS_REGDATE',
#        'WHOIS_UPDATED_DATE', 'TCP_CONVERSATION_EXCHANGE',
#        'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES',
#        'APP_PACKETS', 'DNS_QUERY_TIMES'],
#       dtype='object')
#
# Feature data types:
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                       object
# SERVER                        object
# CONTENT_LENGTH               float64
# WHOIS_COUNTRY                 object
# WHOIS_STATEPRO                object
# WHOIS_REGDATE                 object
# WHOIS_UPDATED_DATE            object
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# ...

# %%
# Which column contains the feature we will predict? What is the code standing for benign vs malicious websites?
# Target variable analysis
target = websites['Type'].value_counts()
print("\nTarget distribution (TYPE):")
print(target)
# target : TYPE , Understand the distribution of Benign (0) vs Malicious (1) websites
# Out:
# Target distribution (TYPE):
# Type
# 0    1565
# 1     216
# Name: count, dtype: int64

# %%
# 0 for bening 1 for maliciuos websites
# target : TYPE , Understand the distribution of Benign (0) vs Malicious (1) websites

# %%
# Do we need to transform any of the columns from categorical to ordinal values? If so what are these columns?

## CHARSET & WHOIS_COUNTRY change from categorical to ordinal
## WHOIS_REGDATE & WHOIS_UPDATED_DATE to datetime type
## CONTENT_LENGTH missing values with the media

# %%
# Date Processing
# Converting to datetime objects as requested
features['WHOIS_REGDATE'] = pd.to_datetime(features['WHOIS_REGDATE'], errors='coerce')
features['WHOIS_UPDATED_DATE'] = pd.to_datetime(features['WHOIS_UPDATED_DATE'], errors='coerce')

# Categorical Encoding
# Transforming CHARSET and WHOIS_COUNTRY into numerical dummies
# We do this directly on 'features' to keep all information in one place
features = pd.get_dummies(features, columns=['CHARSET', 'WHOIS_COUNTRY'], drop_first=True)

# Null Value Imputation
# Handling missing values in CONTENT_LENGTH using the median
features['CONTENT_LENGTH'] = features['CONTENT_LENGTH'].fillna(features['CONTENT_LENGTH'].median())

# Create features_clean (Final Numeric Version)
# We drop any non-numeric columns (like datetime) to create the clean training set
features_clean = features.select_dtypes(exclude=['datetime64[ns]', 'object'])

# Check results
print(f"Original features with dates (shape): {features.shape}")
print(f"Clean features for modeling (shape): {features_clean.shape}")
print("\nFirst 5 rows of features_clean:")
features_clean.head()
# Out:
# Original features with dates (shape): (1781, 71)
# Clean features for modeling (shape): (1781, 67)
#
# First 5 rows of features_clean:
#    URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  CONTENT_LENGTH  \
# 0          16                          7           263.0
# 1          16                          6         15087.0
# 2          16                          6           324.0
# 3          17                          6           162.0
# 4          17                          6        124140.0
#
#    TCP_CONVERSATION_EXCHANGE  DIST_REMOTE_TCP_PORT  REMOTE_IPS  APP_BYTES  \
# 0                          7                     0           2        700
# 1                         17                     7           4       1230
# 2                          0                     0           0          0
# 3                         31                    22           3       3812
# 4                         57                     2           5       4278
#
# ...

# %% [markdown]
# #### Next, evaluate if the columns in this dataset are strongly correlated.
#
# In the Mushroom supervised learning lab we did recently, we mentioned we are concerned if our dataset has strongly correlated columns because if it is the case we need to choose certain ML algorithms instead of others. We need to evaluate this for our dataset now.
#
# Luckily, most of the columns in this dataset are ordinal which makes things a lot easier for us. In the next cells below, evaluate the level of collinearity of the data.
#
# We provide some general directions for you to consult in order to complete this step:
#
# 1. You will create a correlation matrix using the numeric columns in the dataset.
#
# 1. Create a heatmap using `seaborn` to visualize which columns have high collinearity.
#
# 1. Comment on which columns you might need to remove due to high collinearity.

# %%
# Your code here
import seaborn as sns
import matplotlib.pyplot as plt

# Filter only existing numerical columns
# This excludes 'URL', 'CHARSET', 'SERVER', and 'WHOIS' columns that are still objects/strings
numeric_features = features.select_dtypes(include=['int64', 'float64'])

# Generate the correlation matrix
# Note: Columns with missing values (like CONTENT_LENGTH) will be handled by .corr() 
# by excluding those specific pairs from the calculation (pairwise deletion)
correlation_matrix = numeric_features.corr()

# Create the heatmap for visualization
plt.figure(figsize=(16, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap - Raw Numerical Features")
plt.show()

# Identify high collinearity pairs (> 0.9)
# We flatten the matrix and filter for values above the threshold
high_corr = correlation_matrix.unstack()
high_corr = high_corr[(abs(high_corr) > 0.9) & (high_corr < 1.0)]

print("Highly Correlated Features found in raw data:")
if not high_corr.empty:
    print(high_corr.sort_values(ascending=False).drop_duplicates())
else:
    print("No features with correlation > 0.9 found.")
# Out:
# Highly Correlated Features found in raw data:
# APP_BYTES                  REMOTE_APP_BYTES             0.999992
# TCP_CONVERSATION_EXCHANGE  APP_PACKETS                  0.997796
#                            REMOTE_APP_PACKETS           0.990848
# REMOTE_APP_PACKETS         SOURCE_APP_PACKETS           0.989285
# URL_LENGTH                 NUMBER_SPECIAL_CHARACTERS    0.917986
# dtype: float64

# %% [markdown]
# ### This is an example to know the feacture importance using a ML model

# %%
! pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
X = websites._get_numeric_data().drop('Type', axis=1)
y = websites.Type

# %%
import xgboost as xgb

from xgboost import XGBClassifier

X = websites._get_numeric_data().drop('Type', axis=1)
y = websites.Type

# 1. Instanciar el modelo
xgb = XGBClassifier()

# 2. Entrenar el modelo instanciado
xgb.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
sort_idx = xgb.feature_importances_.argsort()

# %%
plt.barh(X.columns[sort_idx],xgb.feature_importances_[sort_idx])
plt.show()

# %% [markdown]
#     In the previous plot we can see the feactures with lower weight in the dataset.

# %% [markdown]
# # Challenge 2 - Remove Column Collinearity.
#
# From the heatmap you created, you should have seen at least 3 columns that can be removed due to high collinearity. Remove these columns from the dataset.
#
# Note that you should remove as few columns as you can. You don't have to remove all the columns at once. But instead, try removing one column, then produce the heatmap again to determine if additional columns should be removed. As long as the dataset no longer contains columns that are correlated for over 90%, you can stop. Also, keep in mind when two columns have high collinearity, you only need to remove one of them but not both.
#
# In the cells below, remove as few columns as you can to eliminate the high collinearity in the dataset. Make sure to comment on your way so that the instructional team can learn about your thinking process which allows them to give feedback. At the end, print the heatmap again.

# %%
# Your code here
# Drop only one column to see the impact
# We start with REMOTE_APP_BYTES as it had a nearly perfect correlation (0.999)
features_reduced = features.drop(columns=['REMOTE_APP_BYTES'])

# Select numerical columns again for the new matrix
# This ensures we are only analyzing numbers
numeric_reduced = features_reduced.select_dtypes(include=['int64', 'float64'])
correlation_matrix_v2 = numeric_reduced.corr()

# Plot the second Heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix_v2, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Heatmap after removing REMOTE_APP_BYTES")
plt.show()

# Check remaining high correlation pairs (> 0.9)
# We flatten and filter again to see what is still above the 90% threshold
high_corr_v2 = correlation_matrix_v2.unstack().sort_values(ascending=False)
high_corr_v2 = high_corr_v2[(abs(high_corr_v2) > 0.9) & (high_corr_v2 < 1.0)]

print("Highly Correlated Features remaining:")
if not high_corr_v2.empty:
    print(high_corr_v2.drop_duplicates())
else:
    print("No features with correlation > 0.9 found.")
# Out:
# Highly Correlated Features remaining:
# TCP_CONVERSATION_EXCHANGE  SOURCE_APP_PACKETS           0.997796
# REMOTE_APP_PACKETS         TCP_CONVERSATION_EXCHANGE    0.990848
# SOURCE_APP_PACKETS         REMOTE_APP_PACKETS           0.989285
# URL_LENGTH                 NUMBER_SPECIAL_CHARACTERS    0.917986
# dtype: float64

# %%
# REMOVE THE 4 COLUMNS WITH MORE COLLINEARITY
import seaborn as sns
import matplotlib.pyplot as plt

# Define the list of columns to drop
# We include the previous one plus the 3 most redundant ones from your result
columns_to_remove = [ 
    'REMOTE_APP_BYTES',
    'APP_PACKETS', 
    'REMOTE_APP_PACKETS', 
    'NUMBER_SPECIAL_CHARACTERS',
    'SOURCE_APP_PACKETS'
]

#  Drop the columns from the 'features' dataframe
features_reduced = features.drop(columns=columns_to_remove)

#  Filter numeric columns for the new correlation matrix
numeric_reduced = features_reduced.select_dtypes(include=['int64', 'float64'])
correlation_matrix_v3 = numeric_reduced.corr()

#  Generate the Heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix_v3, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Heatmap after removing 4 highly correlated features")
plt.show()

#  Check remaining high correlation pairs (> 0.9)
high_corr_v3 = correlation_matrix_v3.unstack().sort_values(ascending=False)
high_corr_v3 = high_corr_v3[(abs(high_corr_v3) > 0.9) & (high_corr_v3 < 1.0)]

print("Highly Correlated Features remaining:")
if not high_corr_v3.empty:
    print(high_corr_v3.drop_duplicates())
else:
    print("No features with correlation > 0.9 found. The dataset is now clean!")
# Out:
# Highly Correlated Features remaining:
# No features with correlation > 0.9 found. The dataset is now clean!

# %% [markdown]
# # Challenge 3 - Handle Missing Values
#
# The next step would be handling missing values. **We start by examining the number of missing values in each column, which you will do in the next cell.**

# %%
# Examine the number of missing values in each column
missing_values_count = websites.isna().sum()

# Display the result
print("--- Missing values per column ---")
print(missing_values_count)
# Out:
# --- Missing values per column ---
# URL                            0
# URL_LENGTH                     0
# NUMBER_SPECIAL_CHARACTERS      0
# CHARSET                        7
# SERVER                       176
# CONTENT_LENGTH               812
# WHOIS_COUNTRY                306
# WHOIS_STATEPRO               362
# WHOIS_REGDATE                127
# WHOIS_UPDATED_DATE           139
# TCP_CONVERSATION_EXCHANGE      0
# DIST_REMOTE_TCP_PORT           0
# REMOTE_IPS                     0
# APP_BYTES                      0
# SOURCE_APP_PACKETS             0
# REMOTE_APP_PACKETS             0
# SOURCE_APP_BYTES               0
# REMOTE_APP_BYTES               0
# APP_PACKETS                    0
# DNS_QUERY_TIMES                1
# Type                           0
# dtype: int64

# %%
# Your code here
# Check for missing values in the processed features dataset
# We use features_final_clean to see the state of our current variables
missing_values_count = features_reduced.isnull().sum()

# Filter to show only columns that actually have missing values
# This makes the output much cleaner and easier to read
columns_with_nulls = missing_values_count[missing_values_count > 0]

# Calculate the percentage of missing values per column
# This helps decide whether to fill (impute) or drop a column
missing_percentage = (columns_with_nulls / len(features_reduced)) * 100

# Create a summary table
missing_summary = pd.DataFrame({
    'Total Missing': columns_with_nulls,
    'Percentage (%)': missing_percentage
}).sort_values(by='Total Missing', ascending=False)

print("Summary of Missing Values:")
print(missing_summary)
# Out:
# Summary of Missing Values:
#                     Total Missing  Percentage (%)
# WHOIS_REGDATE                1205       67.658619
# WHOIS_UPDATED_DATE           1122       62.998316
# WHOIS_STATEPRO                362       20.325660
# SERVER                        176        9.882089
# DNS_QUERY_TIMES                 1        0.056148

# %%
# First we will drop the columns with more than 50% of missing data
# As seen in our summary, WHOIS_REGDATE (67.6%) and WHOIS_UPDATED_DATE (63.0%) exceed this threshold

# Define the columns to drop
columns_over_50 = ['WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']

# Drop them from the dataset (assuming your active dataframe is 'features_reduced' or 'websites')
features_reduced = features_reduced.drop(columns=columns_over_50)

# Verify they were dropped
print("Columns successfully dropped. Remaining columns:", features_reduced.shape[1])
# Out:
# Columns successfully dropped. Remaining columns: 64

# %%
target
# Out:
# Type
# 0    1565
# 1     216
# Name: count, dtype: int64

# %%
# 1. Definir correctamente el target desde el dataset original
target = websites['Type']

# 2. Eliminar las dos columnas con más del 50% de nulos 
# (Usamos errors='ignore' para que no falle si ya se habían borrado antes)
columns_over_50 = ['WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']
features_clean_cols = features_reduced.drop(columns=columns_over_50, errors='ignore')

# 3. Combinar temporalmente features y target para borrar las filas con nulos
temp_df = pd.concat([features_clean_cols, target], axis=1)

# 4. Eliminar las filas que aún tienen algún dato nulo 
temp_df_clean = temp_df.dropna()

# 5. Volver a separar en features y target finales
# (También usamos errors='ignore' por seguridad)
features_no_nulls = temp_df_clean.drop(columns=['Type'], errors='ignore') 
target_final = temp_df_clean['Type']

# --- COMPROBACIONES FINALES ---
print(f"Columnas finales en features: {features_no_nulls.shape[1]}")
print(f"Filas finales tras limpiar nulos: {len(features_no_nulls)}")
print(f"Tamaño del target: {len(target_final)}")
print(f"Valores nulos restantes totales: {features_no_nulls.isnull().sum().sum()}")
# Out:
# Columnas finales en features: 64
# Filas finales tras limpiar nulos: 1266
# Tamaño del target: 1266
# Valores nulos restantes totales: 0

# %% [markdown]
# #### Again, examine the number of missing values in each column.
#
#     If all cleaned, proceed. Otherwise, go back and do more cleaning.

# %%
# Examine missing values in each columnç
# 1. Count missing values per column
# .isnull() identifies NaNs, .sum() counts them
missing_values = features_no_nulls.isnull().sum()

# 2. Calculate the percentage of missing values
# This helps decide if a column has too much missing data to be useful
missing_percentage = (missing_values / len(features_no_nulls)) * 100

# 3. Combine both into a summary DataFrame
missing_df = pd.DataFrame({
    'Total Missing': missing_values,
    'Percentage (%)': missing_percentage
})

# 4. Filter to show only columns that have at least one missing value
# and sort them from highest to lowest
missing_summary = missing_df[missing_df['Total Missing'] > 0].sort_values(by='Total Missing', ascending=False)

print("Columns with missing values:")
print(missing_summary)
# Out:
# Columns with missing values:
# Empty DataFrame
# Columns: [Total Missing, Percentage (%)]
# Index: []

# %% [markdown]
# # Challenge 4 - Handle `WHOIS_*` Categorical Data

# %% [markdown]
# There are several categorical columns we need to handle. These columns are:
#
# * `URL`
# * `CHARSET`
# * `SERVER`
# * `WHOIS_COUNTRY`
# * `WHOIS_STATEPRO`
# * `WHOIS_REGDATE`
# * `WHOIS_UPDATED_DATE`
#
# How to handle string columns is always case by case. Let's start by working on `WHOIS_COUNTRY`. Your steps are:
#
# 1. List out the unique values of `WHOIS_COUNTRY`.
# 1. Consolidate the country values with consistent country codes. For example, the following values refer to the same country and should use consistent country code:
#     * `CY` and `Cyprus`
#     * `US` and `us`
#     * `SE` and `se`
#     * `GB`, `United Kingdom`, and `[u'GB'; u'UK']`
#
# #### In the cells below, fix the country values as intructed above.

# %%
websites.WHOIS_COUNTRY.value_counts()
# Out:
# WHOIS_COUNTRY
# US                1103
# CA                  84
# ES                  63
# AU                  35
# PA                  21
# GB                  19
# JP                  11
# UK                  10
# IN                  10
# CN                  10
# CZ                   9
# FR                   9
# NL                   6
# CH                   6
# KR                   5
# [u'GB'; u'UK']       5
# ru                   4
# BS                   4
# AT                   4
# PH                   4
# us                   3
# SC                   3
# DE                   3
# BE                   3
# HK                   3
# TR                   3
# SE                   3
# KY                   3
# RU                   2
# NO                   2
# SI                   2
# IL                   2
# KG                   2
# BR                   2
# UA                   2
# Cyprus               2
# UY                   2
# se                   1
# LU                   1
# ...

# %%
# Your code here
good_country = {'None':'None', 
                'US':'US', 
                'SC':'SC', 
                'GB':'UK', 
                'UK':'UK', 
                'RU':'RU', 
                'AU':'AU', 
                'CA':'CA',
                'PA':'PA',
                'se':'SE', 
                'IN':'IN',
                'LU':'LU', 
                'TH':'TH', 
                "[u'GB'; u'UK']":'UK', 
                'FR':'FR',
                'NL':'NL',
                'UG':'UG', 
                'JP':'JP', 
                'CN':'CN', 
                'SE':'SE',
                'SI':'SI', 
                'IL':'IL', 
                'ru':'RU', 
                'KY':'KY', 
                'AT':'AT', 
                'CZ':'CZ', 
                'PH':'PH', 
                'BE':'BE', 
                'NO':'NO', 
                'TR':'TR', 
                'LV':'LV',
                'DE':'DE', 
                'ES':'ES', 
                'BR':'BR', 
                'us':'US', 
                'KR':'KR', 
                'HK':'HK', 
                'UA':'UA', 
                'CH':'CH', 
                'United Kingdom':'UK',
                'BS':'BS', 
                'PK':'PK', 
                'IT':'IT', 
                'Cyprus':'CY', 
                'BY':'BY', 
                'AE':'AE', 
                'IE':'IE', 
                'UY':'UY', 
                'KG':'KG'}

# Any value not found in the dictionary will be temporarily turned into NaN
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].map(good_country)

#  Fill all actual NaN values with the string 'None'
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].fillna('None')

# Check the results
print(websites['WHOIS_COUNTRY'].value_counts())
# Out:
# WHOIS_COUNTRY
# US      1106
# None     306
# CA        84
# ES        63
# AU        35
# UK        35
# PA        21
# JP        11
# CN        10
# IN        10
# FR         9
# CZ         9
# NL         6
# CH         6
# RU         6
# KR         5
# BS         4
# SE         4
# AT         4
# PH         4
# SC         3
# BE         3
# HK         3
# DE         3
# TR         3
# KY         3
# CY         2
# SI         2
# KG         2
# UY         2
# NO         2
# BR         2
# IL         2
# UA         2
# LU         1
# LV         1
# TH         1
# UG         1
# PK         1
# BY         1
# IT         1
# IE         1
# AE         1
# Name: count, dtype: int64

# %%
websites.WHOIS_COUNTRY.unique()
# Out:
# array(['None', 'US', 'SC', 'UK', 'RU', 'AU', 'CA', 'PA', 'SE', 'IN', 'LU',
#        'TH', 'FR', 'NL', 'UG', 'JP', 'CN', 'SI', 'IL', 'KY', 'AT', 'CZ',
#        'PH', 'BE', 'NO', 'TR', 'LV', 'DE', 'ES', 'BR', 'KR', 'HK', 'UA',
#        'CH', 'BS', 'PK', 'IT', 'CY', 'BY', 'AE', 'IE', 'UY', 'KG'],
#       dtype=object)

# %%
# 4. Verify results
print("\nCountry distribution after cleaning:")
print(websites['WHOIS_COUNTRY'].value_counts())
# Out:
# Country distribution after cleaning:
# WHOIS_COUNTRY
# US      1106
# None     306
# CA        84
# ES        63
# AU        35
# UK        35
# PA        21
# JP        11
# CN        10
# IN        10
# FR         9
# CZ         9
# NL         6
# CH         6
# RU         6
# KR         5
# BS         4
# SE         4
# AT         4
# PH         4
# SC         3
# BE         3
# HK         3
# DE         3
# TR         3
# KY         3
# CY         2
# SI         2
# KG         2
# UY         2
# NO         2
# BR         2
# IL         2
# UA         2
# LU         1
# LV         1
# TH         1
# UG         1
# PK         1
# BY         1
# IT         1
# IE         1
# AE         1
# Name: count, dtype: int64

# %% [markdown]
# Since we have fixed the country values, can we convert this column to ordinal now?
#
# Not yet. If you reflect on the previous labs how we handle categorical columns, you probably remember we ended up dropping a lot of those columns because there are too many unique values. Too many unique values in a column is not desirable in machine learning because it makes prediction inaccurate. But there are workarounds under certain conditions. One of the fixable conditions is:
#
# #### If a limited number of values account for the majority of data, we can retain these top values and re-label all other rare values.
#
# The `WHOIS_COUNTRY` column happens to be this case. You can verify it by print a bar chart of the `value_counts` in the next cell to verify:

# %%
import matplotlib.pyplot as plt

def print_bar_plot(data_series):
    # Set figure size first
    plt.figure(figsize=(15, 10))
    
    # Extract labels (x) and values (y) from the same series
    # All labels are forced to string to avoid type errors
    x = [str(label) for label in data_series.index]
    y = data_series.values
    
    plt.bar(x, y)
    
    # Customizing the plot for better visibility
    plt.title("Websites Distribution by Country", fontsize=15)
    plt.xticks(rotation=45) # Rotate labels to avoid overlap
    plt.ylabel("Count")
    
    return plt.show()

# %%
# Execution: Pass the value_counts() result directly
# This ensures x and y always have the same shape and order
print_bar_plot(websites.WHOIS_COUNTRY.value_counts())

# %% [markdown]
# #### After verifying, now let's keep the top 10 values of the column and re-label other columns with `OTHER`.

# %%
# Your code here
# 1. Identify the top 10 countries by frequency
top_10_countries = websites['WHOIS_COUNTRY'].value_counts().head(10).index

# 2. Re-label any country not in the top 10 as 'OTHER'
# We use a lambda function to check if each country 'x' is in our top_10 list
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].apply(lambda x: x if x in top_10_countries else 'OTHER')

# 3. Verify the new distribution
print("New Country Distribution (Top 10 + OTHER):")
country_counts = websites['WHOIS_COUNTRY'].value_counts()
print(country_counts)

# 4. Visualize the cleaner distribution using your previous function
# Since the function is already defined, we just call it
print_bar_plot(country_counts)
# Out:
# New Country Distribution (Top 10 + OTHER):
# WHOIS_COUNTRY
# US       1106
# None      306
# OTHER     100
# CA         84
# ES         63
# AU         35
# UK         35
# PA         21
# JP         11
# IN         10
# CN         10
# Name: count, dtype: int64

# %% [markdown]
# Now since `WHOIS_COUNTRY` has been re-labelled, we don't need `WHOIS_STATEPRO` any more because the values of the states or provinces may not be relevant any more. We'll drop this column.
#
# In addition, we will also drop `WHOIS_REGDATE` and `WHOIS_UPDATED_DATE`. These are the registration and update dates of the website domains. Not of our concerns.
#
# #### In the next cell, drop `['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']`.

# %%
# Your code here
# 1. List the columns to be removed
columns_to_drop = ['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']

# 2. Drop the columns from the dataframe
# axis=1 indicates we are dropping columns, not rows
websites.drop(labels=columns_to_drop, axis=1, inplace=True)

# 3. Verify the columns are gone
print("Remaining columns in the dataset:")
print(websites.columns)

# 4. Check the current shape of the dataframe
print(f"\nNew dataframe shape: {websites.shape}")
# Out:
# Remaining columns in the dataset:
# Index(['URL', 'URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CHARSET', 'SERVER',
#        'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'TCP_CONVERSATION_EXCHANGE',
#        'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES',
#        'APP_PACKETS', 'DNS_QUERY_TIMES', 'Type'],
#       dtype='object')
#
# New dataframe shape: (1781, 18)

# %% [markdown]
# # Challenge 5 - Handle Remaining Categorical Data & Convert to Ordinal
#
# Now print the `dtypes` of the data again. Besides `WHOIS_COUNTRY` which we already fixed, there should be 3 categorical columns left: `URL`, `CHARSET`, and `SERVER`.

# %%
# Your code here
# 1. Print the dtypes of the data again to verify the remaining categorical columns
print("--- Current Data Types ---")
print(websites.dtypes)
# Out:
# --- Current Data Types ---
# URL                           object
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CHARSET                       object
# SERVER                        object
# CONTENT_LENGTH               float64
# WHOIS_COUNTRY                 object
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# SOURCE_APP_PACKETS             int64
# REMOTE_APP_PACKETS             int64
# SOURCE_APP_BYTES               int64
# REMOTE_APP_BYTES               int64
# APP_PACKETS                    int64
# DNS_QUERY_TIMES              float64
# Type                           int64
# dtype: object

# %% [markdown]
# #### `URL` is easy. We'll simply drop it because it has too many unique values that there's no way for us to consolidate.

# %%
# Your code here
# Drop the 'URL' column because it has too many unique values (high cardinality)
# We use inplace=True to modify the dataframe directly
websites.drop(columns=['URL'], inplace=True)

# Verify it was successfully dropped
print("Remaining columns after dropping 'URL':")
print(websites.columns)

# Check the new shape of the dataframe
print(f"\nNew dataframe shape: {websites.shape}")
# Out:
# Remaining columns after dropping 'URL':
# Index(['URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CHARSET', 'SERVER',
#        'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'TCP_CONVERSATION_EXCHANGE',
#        'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES',
#        'APP_PACKETS', 'DNS_QUERY_TIMES', 'Type'],
#       dtype='object')
#
# New dataframe shape: (1781, 17)

# %% [markdown]
# #### Print the unique value counts of `CHARSET`. You see there are only a few unique values. So we can keep it as it is.

# %%
# Your code here
# Print the unique value counts of the 'CHARSET' column
charset_counts = websites['CHARSET'].value_counts()

print("--- Unique values in CHARSET ---")
print(charset_counts)
# Out:
# --- Unique values in CHARSET ---
# CHARSET
# UTF-8           676
# ISO-8859-1      427
# utf-8           379
# us-ascii        155
# iso-8859-1      134
# windows-1251      1
# ISO-8859          1
# windows-1252      1
# Name: count, dtype: int64

# %% [markdown]
# `SERVER` is a little more complicated. Print its unique values and think about how you can consolidate those values.
#
# #### Before you think of your own solution, don't read the instructions that come next.

# %%
# Your code here
# Print the unique value counts of the 'SERVER' column
server_counts = websites['SERVER'].value_counts()

print("--- Unique values in SERVER ---")
print(server_counts)

# Print the total number of unique categories to see the scale of the problem
total_unique_servers = websites['SERVER'].nunique()
print(f"\nTotal unique server strings: {total_unique_servers}")
# Out:
# --- Unique values in SERVER ---
# SERVER
# Apache                                                           386
# nginx                                                            211
# Microsoft-HTTPAPI/2.0                                            113
# cloudflare-nginx                                                  94
# Microsoft-IIS/7.5                                                 51
#                                                                 ...
# My Arse                                                            1
# IdeaWebServer/v0.80                                                1
# Apache/2.4.17 (Unix) OpenSSL/1.0.1e-fips PHP/5.6.19                1
# Microsoft-IIS/7.5; litigation_essentials.lexisnexis.com  9999      1
# Apache/2.2.16 (Debian)                                             1
# Name: count, Length: 238, dtype: int64
#
# Total unique server strings: 238

# %% [markdown]
# Although there are so many unique values in the `SERVER` column, there are actually only 3 main server types: `Microsoft`, `Apache`, and `nginx`. Just check if each `SERVER` value contains any of those server types and re-label them. For `SERVER` values that don't contain any of those substrings, label with `Other`.
#
# At the end, your `SERVER` column should only contain 4 unique values: `Microsoft`, `Apache`, `nginx`, and `Other`.

# %%
# Count `SERVER` value counts here
# Function to group servers into the 4 requested categories
def group_server(server_name):
    # Convert to string and lowercase to easily check for substrings
    server_lower = str(server_name).lower()
    
    # Check for the main server types
    if 'microsoft' in server_lower:
        return 'Microsoft'
    elif 'apache' in server_lower:
        return 'Apache'
    elif 'nginx' in server_lower:
        return 'nginx'
    else:
        # Anything else (including NaNs or weird names) becomes 'Other'
        return 'Other'

# Apply the function to the SERVER column
websites['SERVER'] = websites['SERVER'].apply(group_server)

# Count SERVER value counts here
server_counts_final = websites['SERVER'].value_counts()

print("--- Final SERVER value counts ---")
print(server_counts_final)
# Out:
# --- Final SERVER value counts ---
# SERVER
# Apache       643
# Other        504
# nginx        436
# Microsoft    198
# Name: count, dtype: int64

# %% [markdown]
# OK, all our categorical data are fixed now. **Let's convert them to ordinal data using Pandas' `get_dummies` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)).** Make sure you drop the categorical columns by passing `drop_first=True` to `get_dummies` as we don't need them any more. **Also, assign the data with dummy values to a new variable `website_dummy`.**

# %%
# Your code here
# Convert categorical columns to dummy variables
# drop_first=True drops the first dummy column for each feature to avoid the dummy variable trap
website_dummy = pd.get_dummies(websites, drop_first=True)

# Print the new shape to see how many columns were created
print(f"Original dataframe shape: {websites.shape}")
print(f"New dataframe shape: {website_dummy.shape}")

# Let's take a quick look at the new columns
print("\n--- Current Columns in website_dummy ---")
print(website_dummy.columns.tolist())

# Preview the first few rows
website_dummy.head()
# Out:
# Original dataframe shape: (1781, 17)
# New dataframe shape: (1781, 34)
#
# --- Current Columns in website_dummy ---
# ['URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CONTENT_LENGTH', 'TCP_CONVERSATION_EXCHANGE', 'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS', 'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES', 'APP_PACKETS', 'DNS_QUERY_TIMES', 'Type', 'CHARSET_ISO-8859-1', 'CHARSET_UTF-8', 'CHARSET_iso-8859-1', 'CHARSET_us-ascii', 'CHARSET_utf-8', 'CHARSET_windows-1251', 'CHARSET_windows-1252', 'SERVER_Microsoft', 'SERVER_Other', 'SERVER_nginx', 'WHOIS_COUNTRY_CA', 'WHOIS_COUNTRY_CN', 'WHOIS_COUNTRY_ES', 'WHOIS_COUNTRY_IN', 'WHOIS_COUNTRY_JP', 'WHOIS_COUNTRY_None', 'WHOIS_COUNTRY_OTHER', 'WHOIS_COUNTRY_PA', 'WHOIS_COUNTRY_UK', 'WHOIS_COUNTRY_US']
#    URL_LENGTH  NUMBER_SPECIAL_CHARACTERS  CONTENT_LENGTH  \
# 0          16                          7           263.0
# 1          16                          6         15087.0
# ...

# %% [markdown]
# Now, inspect `website_dummy` to make sure the data and types are intended - there shouldn't be any categorical columns at this point.

# %%
# Your code here
# 1. Check the data types of all columns
print("--- Data Types in website_dummy ---")
print(website_dummy.dtypes)

# 2. Use .info() for a complete summary (checks for nulls and data types)
print("\n--- Comprehensive DataFrame Info ---")
website_dummy.info()
# Out:
# --- Data Types in website_dummy ---
# URL_LENGTH                     int64
# NUMBER_SPECIAL_CHARACTERS      int64
# CONTENT_LENGTH               float64
# TCP_CONVERSATION_EXCHANGE      int64
# DIST_REMOTE_TCP_PORT           int64
# REMOTE_IPS                     int64
# APP_BYTES                      int64
# SOURCE_APP_PACKETS             int64
# REMOTE_APP_PACKETS             int64
# SOURCE_APP_BYTES               int64
# REMOTE_APP_BYTES               int64
# APP_PACKETS                    int64
# DNS_QUERY_TIMES              float64
# Type                           int64
# CHARSET_ISO-8859-1              bool
# CHARSET_UTF-8                   bool
# CHARSET_iso-8859-1              bool
# CHARSET_us-ascii                bool
# CHARSET_utf-8                   bool
# CHARSET_windows-1251            bool
# CHARSET_windows-1252            bool
# SERVER_Microsoft                bool
# SERVER_Other                    bool
# SERVER_nginx                    bool
# ...

# %% [markdown]
# # Challenge 6 - Modeling, Prediction, and Evaluation
#
# We'll start off this section by splitting the data to train and test. **Name your 4 variables `X_train`, `X_test`, `y_train`, and `y_test`. Select 80% of the data for training and 20% for testing.**

# %%
from sklearn.model_selection import train_test_split

# Your code here:

# 1. Separar las características (X) de la variable objetivo a predecir (y)
# X será todo el dataframe MENOS la columna 'Type'
X = website_dummy.drop(columns=['Type'])

# y será ÚNICAMENTE la columna 'Type' (lo que queremos predecir)
y = website_dummy['Type']

# 2. Dividir los datos (80% entrenamiento, 20% prueba)
# Usamos random_state=42 para que la división aleatoria sea siempre la misma 
# y tus resultados sean reproducibles si vuelves a ejecutar la celda.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# 3. Comprobar las dimensiones para asegurar que el 80/20 se ha aplicado correctamente
print(f"Dimensiones de X_train (Entrenamiento): {X_train.shape}")
print(f"Dimensiones de X_test (Prueba): {X_test.shape}")
print(f"Dimensiones de y_train: {y_train.shape}")
print(f"Dimensiones de y_test: {y_test.shape}")
# Out:
# Dimensiones de X_train (Entrenamiento): (1424, 33)
# Dimensiones de X_test (Prueba): (357, 33)
# Dimensiones de y_train: (1424,)
# Dimensiones de y_test: (357,)

# %% [markdown]
# #### In this lab, we will try two different models and compare our results.
#
# The first model we will use in this lab is logistic regression. We have previously learned about logistic regression as a classification algorithm. In the cell below, load `LogisticRegression` from scikit-learn and initialize the model.

# %%
# Your code here:
# Importar el modelo desde la librería scikit-learn
from sklearn.linear_model import LogisticRegression

# Inicializar el modelo
# (Añadimos max_iter=1000 como buena práctica para asegurarnos de que el algoritmo 
# tenga tiempo suficiente para encontrar el patrón matemático sin dar un aviso de error)
lr_model = LogisticRegression(max_iter=1000)

print("¡Modelo de Regresión Logística inicializado correctamente!")
# Out:
# ¡Modelo de Regresión Logística inicializado correctamente!

# %% [markdown]
# Next, fit the model to our training data. We have already separated our data into 4 parts. Use those in your model.

# %%
# Your code here:
# 1. SOLUCIÓN A LOS NULOS: Rellenar los valores vacíos con la mediana
# (Hacemos esto tanto en Train como en Test para que los algoritmos no colapsen)
X_train = X_train.fillna(X_train.median())
X_test = X_test.fillna(X_train.median()) # Rellenamos test usando la mediana de train

# 2. ENTRENAR EL MODELO: Ajustar la Regresión Logística a los datos de entrenamiento
lr_model.fit(X_train, y_train)

print("¡Modelo entrenado con éxito!")
# Out:
# ¡Modelo entrenado con éxito!
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# finally, import `confusion_matrix` and `accuracy_score` from `sklearn.metrics` and fit our testing data. Assign the fitted data to `y_pred` and print the confusion matrix as well as the accuracy score

# %%
# Your code here:
from sklearn.metrics import confusion_matrix, accuracy_score

# 1. Realizar las predicciones con nuestros datos de prueba (X_test)
y_pred = lr_model.predict(X_test)

# 2. Calcular la matriz de confusión y la precisión comparando lo real con lo predicho
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

# 3. Imprimir los resultados
print("--- Confusión Matrix ---")
print(cm)

print("\n--- Accuracy ---")
# Lo multiplicamos por 100 para verlo en formato porcentaje
print(f"{acc * 100:.2f}%")
# Out:
# --- Confusión Matrix ---
# [[299   7]
#  [ 21  30]]
#
# --- Accuracy ---
# 92.16%

# %% [markdown]
# What are your thoughts on the performance of the model? Write your conclusions below.

# %% [markdown]
# ### Your conclusions here:
# - Conclusions on Model Performance (Logistic Regression)
# At first glance, an overall accuracy of 92.16% seems like an outstanding result. However, upon closer examination of the Confusion Matrix, we observe critical nuances that are vital in a cybersecurity context:
#
#    - The impact of class imbalance: The dataset has a clear majority of secure websites compared to malicious ones. If a model blindly predicted that "all websites are secure," it would already achieve high accuracy. Therefore, overall accuracy is not the best metric to evaluate success here.
#
#    - Excellent False Positive Control: The model only incorrectly classified 7 secure websites as malicious. This means it has high accuracy; when an alarm is triggered, it is almost always correct. In a production environment, this is beneficial because it prevents overwhelming the security team with false alerts.
#
#    - The weak point: False Negatives: The model missed 21 malicious websites, classifying them as safe (compared to the 30 it detected). This gives us a recall (sensitivity) of approximately 58.8% for the minority class. In cybersecurity, this represents a significant risk, as almost 40% of real threats are managing to evade the model.
#
# **Final conclusion:**
# Logistic Regression works as an excellent baseline model, establishing a lower performance limit of 92%. However, being a linear model, it struggles to capture the full complexity of malicious websites that attempt to disguise themselves. To significantly reduce these 21 false negatives and improve recall, the natural next step would be to evolve towards algorithms based on tree sets. Implementing a Random Forest or applying gradient boosting techniques like XGBoost will allow for modeling much deeper nonlinear relationships and natively handling web traffic imbalances.

# %% [markdown]
# #### Our second algorithm is is DecisionTreeClassifier
#
# Though is it not required, we will fit a model using the training data and then test the performance of the model using the testing data. Start by loading `DecisionTreeClassifier` from scikit-learn and then initializing and fitting the model. We'll start off with a model where max_depth=3

# %%
# Your code here:
from sklearn.tree import DecisionTreeClassifier

# 1. Inicializar el modelo de Árbol de Decisión limitando la profundidad a 3
# Añadimos random_state=42  para que el resultado sea el mismo siempre que se ejecute
tree_model = DecisionTreeClassifier(max_depth=3, random_state=42)

# fit
tree_model.fit(X_train, y_train)

print("¡Modelo de Árbol de Decisión entrenado con éxito!")
# Out:
# ¡Modelo de Árbol de Decisión entrenado con éxito!

# %% [markdown]
# To test your model, compute the predicted probabilities, decide 0 or 1 using a threshold of 0.5 and print the confusion matrix as well as the accuracy score (on the test set!)

# %%
# Your code here:
import numpy as np

# 1. Calculate the predicted probabilities (predict_proba)
# This returns two columns: probability of class 0 (Safe) and class 1 (Malicious).
# We use [:, 1] to keep only the column for the probability of being Malicious.
y_pred_proba = tree_model.predict_proba(X_test)[:, 1]

# 2. Decide 0 or 1 using a threshold of 0.5

y_pred_tree = (y_pred_proba >= 0.5).astype(int)

# 3. Calculate the confusion matrix and accuracy score
cm_tree = confusion_matrix(y_test, y_pred_tree)
acc_tree = accuracy_score(y_test, y_pred_tree)

# 4. Print the results
print("--- Confusion Matrix (Decision Tree) ---")
print(cm_tree)

print("\n--- Accuracy Score ---")
print(f"{acc_tree * 100:.2f}%")
# Out:
# --- Confusion Matrix (Decision Tree) ---
# [[306   0]
#  [ 36  15]]
#
# --- Accuracy Score ---
# 89.92%

# %% [markdown]
# #### We'll create another DecisionTreeClassifier model with max_depth=5.
# Initialize and fit the model below and print the confusion matrix and the accuracy score.

# %%
# Your code here:
# 1. Initialize the Decision Tree model with max_depth=5
# (We keep random_state=42 for reproducibility)
tree_model_5 = DecisionTreeClassifier(max_depth=5, random_state=42)

# 2. Fit the model using the training data
tree_model_5.fit(X_train, y_train)

# 3. Predict the labels for the testing data
# (Here we can use .predict() directly, which automatically uses the 0.5 threshold)
y_pred_tree_5 = tree_model_5.predict(X_test)

# 4. Calculate the confusion matrix and accuracy score
cm_tree_5 = confusion_matrix(y_test, y_pred_tree_5)
acc_tree_5 = accuracy_score(y_test, y_pred_tree_5)

# 5. Print the results
print("--- Confusion Matrix (Decision Tree, max_depth=5) ---")
print(cm_tree_5)

print("\n--- Accuracy Score ---")
print(f"{acc_tree_5 * 100:.2f}%")
# Out:
# --- Confusion Matrix (Decision Tree, max_depth=5) ---
# [[300   6]
#  [ 17  34]]
#
# --- Accuracy Score ---
# 93.56%

# %% [markdown]
# Did you see an improvement in the confusion matrix when increasing max_depth to 5? Did you see an improvement in the accuracy score? Write your conclusions below.

# %% [markdown]
# ### Your conclusions here:
# Yes, there was a significant improvement in both the confusion matrix and the accuracy score when increasing the max_depth from 3 to 5.
#
# Here is the breakdown of the improvements:
#
# - Accuracy Score: The overall accuracy jumped from 89.92% to 93.56%, making this the best-performing model so far (even beating the Logistic Regression's 92.16%).
#
# - Reduction in False Negatives (The biggest win): In the max_depth=3 model, 36 malicious websites slipped through undetected. By increasing the depth to 5, the model dropped those False Negatives to just 17. Furthermore, it correctly identified 34 malicious websites (True Positives), compared to only 15 in the previous model.
#
# - The Trade-off: We did see a slight increase in False Positives (safe websites flagged as malicious), going from 0 to 6. However, in the context of cybersecurity, this is a highly acceptable trade-off. It is much safer to accidentally block a few legitimate sites than to let dozens of malicious threats pass through your filters.
#
# **Final takeaway:**
# The max_depth=3 model was suffering from underfitting—it was too simple to capture the complex traits of a malicious website. By allowing the tree to ask two more levels of questions (max_depth=5), the model found a "sweet spot" where it could learn deeper patterns without memorizing the noise, resulting in a much stronger and safer predictive model.

# %% [markdown]
# <!-- Add your conclusion here -->

# %% [markdown]
# # Bonus Challenge - Feature Scaling
#
# Problem-solving in machine learning is iterative. You can improve your model prediction with various techniques (there is a sweetspot for the time you spend and the improvement you receive though). Now you've completed only one iteration of ML analysis. There are more iterations you can conduct to make improvements. In order to be able to do that, you will need deeper knowledge in statistics and master more data analysis techniques. In this bootcamp, we don't have time to achieve that advanced goal. But you will make constant efforts after the bootcamp to eventually get there.
#
# However, now we do want you to learn one of the advanced techniques which is called *feature scaling*. The idea of feature scaling is to standardize/normalize the range of independent variables or features of the data. This can make the outliers more apparent so that you can remove them. This step needs to happen during Challenge 6 after you split the training and test data because you don't want to split the data again which makes it impossible to compare your results with and without feature scaling. For general concepts about feature scaling, click [here](https://en.wikipedia.org/wiki/Feature_scaling). To read deeper, click [here](https://medium.com/greyatom/why-how-and-when-to-scale-your-features-4b30ab09db5e).
#
# In the next cell, attempt to improve your model prediction accuracy by means of feature scaling. A library you can utilize is `sklearn.preprocessing.RobustScaler` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)). You'll use the `RobustScaler` to fit and transform your `X_train`, then transform `X_test`. You will use logistic regression to fit and predict your transformed data and obtain the accuracy score in the same way. Compare the accuracy score with your normalized data with the previous accuracy data. Is there an improvement?

# %%
# Your code here
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score

# 1. Initialize the RobustScaler
scaler = RobustScaler()

# 2. Fit the scaler on the training data AND transform it
# (We only 'fit' on the training data to prevent data leakage from the test set)
X_train_scaled = scaler.fit_transform(X_train)

# 3. Transform the testing data using the already fitted scaler
X_test_scaled = scaler.transform(X_test)

# 4. Initialize a fresh Logistic Regression model
lr_model_scaled = LogisticRegression(max_iter=1000, random_state=42)

# 5. Fit the model using the SCALED training data
lr_model_scaled.fit(X_train_scaled, y_train)

# 6. Predict the labels for the SCALED testing data
y_pred_scaled = lr_model_scaled.predict(X_test_scaled)

# 7. Calculate the confusion matrix and accuracy score
cm_scaled = confusion_matrix(y_test, y_pred_scaled)
acc_scaled = accuracy_score(y_test, y_pred_scaled)

# 8. Print the results to compare
print("--- Confusion Matrix (Scaled Logistic Regression) ---")
print(cm_scaled)

print("\n--- Accuracy Score ---")
print(f"{acc_scaled * 100:.2f}%")
# Out:
# --- Confusion Matrix (Scaled Logistic Regression) ---
# [[302   4]
#  [ 26  25]]
#
# --- Accuracy Score ---
# 91.60%

# %% [markdown]
# ## Comments:

# %% [markdown]
# **Did I see an improvement in the accuracy score?**
# Counterintuitively, no. The overall accuracy slightly decreased from 92.16% (unscaled Logistic Regression) to 91.60% (scaled with RobustScaler).
#
# **Detailed Analysis of the Confusion Matrix:**
# While the accuracy dropped, the distribution of errors shifted:
#
# - False Positives improved: The model became more conservative, only misclassifying 4 safe websites as malicious (down from 7).
#
# - False Negatives worsened: The model missed 26 malicious websites (up from 21).
#
# **Why did this happen?**
# In many datasets, outliers are noise. However, in cybersecurity (malicious website detection), extreme values (outliers)—such as an abnormally high CONTENT_LENGTH or unusual packet sizes—are often the exact signals that identify a threat. RobustScaler is specifically designed to minimize the influence of outliers by scaling the data according to the Interquartile Range (IQR). By diminishing the impact of these extreme values, we made the mathematical computation stable (resolving the previous ConvergenceWarning), but we likely blurred the very features that the linear model needed to flag malicious sites effectively.
#
# #### **Conclusion:** Feature scaling is essential for distance-based and linear models to converge properly. However, this iteration proves that for this specific dataset, tree-based models (like our max_depth=5 Decision Tree, which achieved 93.56% accuracy and requires no feature scaling) are natively much better suited to capture the complex, non-linear relationships and valuable outliers inherent in cybersecurity data.
